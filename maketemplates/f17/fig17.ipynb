# %%
import pylab as plt
plt.rcParams['font.size'] = 35

# %%
import pandas as pd
import numpy as np

# %%
dm15 = pd.read_csv("table5_dm15.csv", header=None, names=["filter","Ibc","Ibc-","Ibc+","Ib","Ib-","Ib+","IIb","IIb-","IIb+",
                                  "Ic","Ic-","Ic+","Ic-bl","Ic-bl-","Ic-bl+","Ibn","Ibn-","Ibn+",""], 
            index_col=None, sep=",")
                                  
dm15.replace("'", "", inplace=True)
dm15
# Out:
#    filter   Ibc  Ibc-  Ibc+    Ib   Ib-   Ib+   IIb  IIb-  IIb+    Ic   Ic-  \
# 0      w2  0.88 -0.09  0.61   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1      m2  1.19 -1.16  1.00   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2      w1  1.13 -0.22  0.87   NaN   NaN   NaN  1.59 -0.63  1.18   NaN   NaN
# 3       u  2.13 -0.49  0.14  1.86 -0.58  0.18  2.07 -0.41  0.20  1.57 -0.16
# 4       U  2.01 -0.52  0.10  1.54 -0.16  0.30  1.88 -0.20  0.22  1.78 -0.26
# 5       B  1.43 -0.18  0.08  1.24 -0.14  0.19  1.40 -0.10  0.08  1.14 -0.16
# 6       g  1.20 -0.26  0.10  1.13 -0.17  0.12  1.10 -0.14  0.11  0.92 -0.24
# 7       V  0.87 -0.17  0.14  0.84 -0.08  0.10  0.88 -0.09  0.08  0.86 -0.10
# 8       r  0.60 -0.17  0.19  0.63 -0.09  0.16  0.69 -0.07  0.06  0.64 -0.17
# 9       R  0.64 -0.19  0.11  0.61 -0.08  0.13  0.64 -0.14  0.08  0.73 -0.16
# 10      i  0.36 -0.10  0.11  0.52 -0.11  0.14  0.49 -0.06  0.06  0.47 -0.11
# 11      I  0.43 -0.11  0.04  0.46 -0.05  0.15  0.53 -0.04  0.04  0.56 -0.14
# 12      J  0.10 -0.02  0.00  0.38 -0.06  0.06  0.38 -0.04  0.05  0.43 -0.12
# 13      H -0.03 -0.02  0.05  0.30 -0.09  0.05  0.29 -0.02  0.02  0.38 -0.09
# 14      K  0.02 -0.02  0.12  0.39 -0.09  0.05   NaN   NaN   NaN  0.55 -0.02
#
#      Ic+  Ic-bl  Ic-bl-  Ic-bl+   Ibn  Ibn-  Ibn+
# 0    NaN    NaN     NaN     NaN   NaN   NaN   NaN NaN
# 1    NaN    NaN     NaN     NaN   NaN   NaN   NaN NaN
# 2    NaN    NaN     NaN     NaN   NaN   NaN   NaN NaN
# 3   0.50    NaN     NaN     NaN   NaN   NaN   NaN NaN
# 4   0.19   1.65   -0.12    0.17   NaN   NaN   NaN NaN
# 5   0.24   1.28   -0.11    0.25  1.07 -0.26  0.27 NaN
# 6   0.08   0.97   -0.15    0.23  1.76 -0.33  0.12 NaN
# 7   0.15   0.92   -0.12    0.11  1.28 -0.54  0.52 NaN
# 8   0.14   0.66   -0.18    0.16  1.70 -0.15  0.14 NaN
# 9   0.10   0.73   -0.06    0.10  1.63 -1.08  0.18 NaN
# 10  0.16   0.65   -0.13    0.10  1.56 -0.11  0.19 NaN
# 11  0.06   0.57   -0.08    0.11  0.66 -0.33  0.99 NaN
# 12  0.14   0.41   -0.16    0.15   NaN   NaN   NaN NaN
# 13  0.07   0.29   -0.10    0.29   NaN   NaN   NaN NaN
# 14  0.03    NaN     NaN     NaN   NaN   NaN   NaN NaN

# %%
dm10 = pd.read_csv("table6_dm10.csv", header=None, names=["filter","Ibc","Ibc-","Ibc+","Ib","Ib-","Ib+","IIb",
                                                       "IIb-","IIb+",
                                  "Ic","Ic-","Ic+","Ic-bl","Ic-bl-","Ic-bl+","Ibn","Ibn-","Ibn+",""], 
            index_col=None, sep=",")
                                  
dm15.replace("'", "", inplace=True)
dm10
# Out:
#    filter   Ibc  Ibc-  Ibc+    Ib   Ib-   Ib+   IIb  IIb-  IIb+    Ic   Ic-  \
# 0      w2 -0.19 -0.04  0.08   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1      m2  0.45 -0.45  0.15   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2      w1 -0.18 -0.37  0.10   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3       u  0.08 -0.06  0.05  0.74 -0.10  0.26  1.89 -0.77  0.34   NaN   NaN
# 4       U  0.02 -0.05  0.05  0.97 -0.39  0.54  0.59 -0.26  0.45   NaN   NaN
# 5       B  0.27 -0.11  0.18  0.71 -0.18  0.52  0.84 -0.31  0.26  0.54 -0.35
# 6       g  0.29 -0.10  0.33  0.98 -0.64  0.32  0.75 -0.20  0.30  0.57 -0.22
# 7       V  0.40 -0.15  0.26  0.50 -0.19  0.29  0.75 -0.27  0.21  0.40 -0.15
# 8       r  0.46 -0.15  0.27  0.54 -0.30  0.16  0.66 -0.10  0.11  0.25 -0.05
# 9       R  0.51 -0.22  0.35  0.45 -0.17  0.22  0.55 -0.14  0.24  0.33 -0.13
# 10      i  0.51 -0.13  0.29  0.41 -0.14  0.14  0.54 -0.10  0.12  0.22 -0.06
# 11      I  0.50 -0.10  0.25  0.28 -0.07  0.13  0.36 -0.05  0.13  0.33 -0.08
# 12      J  0.44 -0.04  0.04  0.19 -0.10  0.17  0.27 -0.05  0.06   NaN   NaN
# 13      H  0.44 -0.01  0.12  0.27 -0.09  0.11  0.34 -0.03  0.03   NaN   NaN
# 14      K  0.49 -0.02  0.01  0.25 -0.06  0.05   NaN   NaN   NaN   NaN   NaN
#
#      Ic+  Ic-bl  Ic-bl-  Ic-bl+  Ibn  Ibn-  Ibn+
# 0    NaN    NaN     NaN     NaN  NaN   NaN   NaN NaN
# 1    NaN    NaN     NaN     NaN  NaN   NaN   NaN NaN
# 2    NaN    NaN     NaN     NaN  NaN   NaN   NaN NaN
# 3    NaN    NaN     NaN     NaN  NaN   NaN   NaN NaN
# 4    NaN    NaN     NaN     NaN  NaN   NaN   NaN NaN
# 5   0.50    NaN     NaN     NaN  NaN   NaN   NaN NaN
# 6   0.18    NaN     NaN     NaN  NaN   NaN   NaN NaN
# 7   0.11   0.64   -0.11    0.25  NaN   NaN   NaN NaN
# 8   0.07   0.71   -0.10    0.13  NaN   NaN   NaN NaN
# 9   0.55   0.89   -0.30    0.22  NaN   NaN   NaN NaN
# 10  0.37   0.45   -0.13    0.20  NaN   NaN   NaN NaN
# 11  0.11   0.38   -0.32    0.51  NaN   NaN   NaN NaN
# 12   NaN    NaN     NaN     NaN  NaN   NaN   NaN NaN
# 13   NaN    NaN     NaN     NaN  NaN   NaN   NaN NaN
# 14   NaN    NaN     NaN     NaN  NaN   NaN   NaN NaN

# %%
dm15["Ib"], dm15["Ib"]
# Out:
# (0      NaN
#  1      NaN
#  2      NaN
#  3     1.86
#  4     1.54
#  5     1.24
#  6     1.13
#  7     0.84
#  8     0.63
#  9     0.61
#  10    0.52
#  11    0.46
#  12    0.38
#  13    0.30
#  14    0.39
#  Name: Ib, dtype: float64,
#  0      NaN
#  1      NaN
#  2      NaN
#  3     1.86
#  4     1.54
#  5     1.24
#  6     1.13
#  7     0.84
#  8     0.63
#  9     0.61
#  10    0.52
#  11    0.46
#  12    0.38
#  13    0.30
#  14    0.39
#  Name: Ib, dtype: float64)

# %%
colors = {"Ibc":"k", 
          "Ib":"SteelBlue", 
          "IIb":"FireBrick", 
          "Ic":"DarkGreen", 
          "Ic-bl":"DarkOrange", 
          "Ibn":"purple"
            }

# %%
offsets = [-0.3, -0.2, -0.1, 0, 0.1, 0.2, 0.3]

# %%
def plotDms(sntype, df, ax, label=None, offset=0.0, ylabel="", 
            grid=False, axis="on", rot=0, yoff=0, loc=None):
    
    
    for i in df.index:
        yerr = [df.loc[i, sntype] + df.loc[i, sntype+"-"] + yoff, 
                  df.loc[i, sntype] + df.loc[i, sntype+"+"] + yoff]
        ax.fill_betweenx(yerr, i*2 + offset - 0.05, i*2 + offset + 0.05, 
                         color = colors[sntype], alpha=0.5)
    ax.scatter((df.index)*2 + offset, df[sntype] + yoff, 
               edgecolor=colors[sntype], label=label, facecolor="white")
            
    #ax.set_xticks(np.arange(len(df["filter"])*2)[::2] + 0.5, 
    #              df['filter'], rotation=rot) ;
    #plt.ylabel(r"$\Delta m_{15}$")
    if not label:
        ax.text(0.85, 0.85, sntype, transform=ax.transAxes)
    else:
        plt.legend(markerscale=2, fontsize=25, loc=loc)
    ax.grid(visible=grid)

# %%
plt.rcParams['font.size'] = 35
fig4 = plt.figure(constrained_layout=True, figsize=(20,15))#, sharex=True, sharey=True)
spec4 = plt.GridSpec(ncols=1, nrows=4, hspace=0, wspace=0)
anno_opts = dict(xy=(0.5, 0.5), xycoords='axes fraction',
                 va='center', ha='center')

ax = fig4.add_subplot(spec4[0:-1, 0])
for i,tp in enumerate(["Ibc", "IIb", "Ib", "Ic", "Ic-bl", "Ibn"]):
    label = tp
    if i > 0: 
        label += " + %d"%i
    plotDms(tp, dm15, ax, label=label, offset=0, 
            ylabel=r"$\Delta m_{15}$", yoff=i, loc='upper left')

ylim = plt.ylim()
plt.yticks(range(*np.array(ylim).astype(int)))
ax.yaxis.grid(True)
plt.ylabel(r"$\Delta m_{15}$ + offset")


ax = fig4.add_subplot(spec4[3, 0])
offsets = []
for i,tp in enumerate(["Ibc", "IIb", "Ib", "Ic", "Ic-bl", "Ibn"]):
    label = ""
    ax.errorbar((dm15.index)*2, dm15[tp], yerr = [-dm15[tp + "-"], 
                                                  dm15[tp + "+"]],
                color=colors[tp],
            fmt=' ', label=label, lw=2, alpha=0.5, ls='none', ms=0)
    ax.scatter((dm15.index)*2, dm15[tp], lw=2,
               edgecolor=colors[tp], facecolor="white")
    
ax.set_xticks(np.arange(len(dm15["filter"])*2)[::2], 
                  dm15['filter']) ;
ax.set_ylim(-0.6,2.9)
ax.set_yticks([0,1,2])
ax.yaxis.grid(True)
plt.ylabel(r"$\Delta m_{15}$")

plt.savefig("dm15.png")
# Out:
# /var/folders/55/hm2934r523sg5qfprlq_4zkm0000gq/T/ipykernel_19455/1084441035.py:25: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string " " (-> linestyle=' '). The keyword argument will take precedence.
#   ax.errorbar((dm15.index)*2, dm15[tp], yerr = [-dm15[tp + "-"],
# /var/folders/55/hm2934r523sg5qfprlq_4zkm0000gq/T/ipykernel_19455/1084441035.py:25: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string " " (-> linestyle=' '). The keyword argument will take precedence.
#   ax.errorbar((dm15.index)*2, dm15[tp], yerr = [-dm15[tp + "-"],
# /var/folders/55/hm2934r523sg5qfprlq_4zkm0000gq/T/ipykernel_19455/1084441035.py:25: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string " " (-> linestyle=' '). The keyword argument will take precedence.
#   ax.errorbar((dm15.index)*2, dm15[tp], yerr = [-dm15[tp + "-"],
# /var/folders/55/hm2934r523sg5qfprlq_4zkm0000gq/T/ipykernel_19455/1084441035.py:25: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string " " (-> linestyle=' '). The keyword argument will take precedence.
#   ax.errorbar((dm15.index)*2, dm15[tp], yerr = [-dm15[tp + "-"],
# /var/folders/55/hm2934r523sg5qfprlq_4zkm0000gq/T/ipykernel_19455/1084441035.py:25: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string " " (-> linestyle=' '). The keyword argument will take precedence.
#   ax.errorbar((dm15.index)*2, dm15[tp], yerr = [-dm15[tp + "-"],
# /var/folders/55/hm2934r523sg5qfprlq_4zkm0000gq/T/ipykernel_19455/1084441035.py:25: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string " " (-> linestyle=' '). The keyword argument will take precedence.
#   ax.errorbar((dm15.index)*2, dm15[tp], yerr = [-dm15[tp + "-"],
# /var/folders/55/hm2934r523sg5qfprlq_4zkm0000gq/T/ipykernel_19455/1084441035.py:39: UserWarning: There are no gridspecs with layoutgrids. Possibly did not call parent GridSpec with the "figure" keyword
#   plt.savefig("dm15.png")
# /Users/fbianco/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: There are no gridspecs with layoutgrids. Possibly did not call parent GridSpec with the "figure" keyword
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.rcParams['font.size'] = 35
fig4 = plt.figure(constrained_layout=True, figsize=(20,15))#, sharex=True, sharey=True)
spec4 = plt.GridSpec(ncols=1, nrows=4, hspace=0, wspace=0)
anno_opts = dict(xy=(0.5, 0.5), xycoords='axes fraction',
                 va='center', ha='center')

ax = fig4.add_subplot(spec4[0:-1, 0])
for i,tp in enumerate(["Ibc", "IIb", "Ib", "Ic", "Ic-bl", "Ibn"]):
    label = tp
    if i > 0: 
        label += " + %d"%i
    plotDms(tp, dm10, ax, label=label, offset=0, 
            ylabel=r"$\Delta m_{15}$", yoff=i, loc='upper left')


ylim = plt.ylim()
plt.yticks(range(*np.array(ylim).astype(int)))
plt.ylabel(r"$\Delta m_{-10}$ + offset")

ax.yaxis.grid(True)

ax = fig4.add_subplot(spec4[3, 0])

for i,tp in enumerate(["Ibc", "IIb", "Ib", "Ic", "Ic-bl", "Ibn"]):
    label = ""
    ax.errorbar((dm10.index)*2, dm10[tp], yerr = [-dm10[tp + "-"], 
                                                  dm10[tp + "+"]],
                color=colors[tp],
            fmt='o', label=label, lw=2, alpha=0.5, ms=0)
    ax.scatter((dm10.index)*2, dm10[tp], lw=2,
               edgecolor=colors[tp], facecolor="white")
ax.set_xticks(np.arange(len(dm15["filter"])*2)[::2], 
                  dm10['filter']) ;
ax.set_ylim(-0.8,2.5)
ax.set_yticks([0,1,2])
ax.yaxis.grid(True)
plt.ylabel(r"$\Delta m_{-10}$")

plt.savefig("dm10.png")
# Out:
# /var/folders/55/hm2934r523sg5qfprlq_4zkm0000gq/T/ipykernel_19455/3544264474.py:39: UserWarning: There are no gridspecs with layoutgrids. Possibly did not call parent GridSpec with the "figure" keyword
#   plt.savefig("dm10.png")
# /Users/fbianco/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: There are no gridspecs with layoutgrids. Possibly did not call parent GridSpec with the "figure" keyword
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.rcParams['font.size'] = 35
fig, ax = plt.subplots(1,1, figsize=(20,10), sharex=True, sharey=True)
for i,tp in enumerate(["Ibc", "IIb", "Ib", "Ic", "Ic-bl", "Ibn"]):
    label = tp
    if i > 0: 
        label += " + %d"%i
    plotDms(tp, dm10, ax, label=label, offset=i*0, ylabel=r"$\Delta m_{-10}$", 
            yoff=i)
plt.savefig("dm10.png")

# %%
plt.rcParams['font.size'] = 15

fig, ax = plt.subplots(6,1, figsize=(10,10), sharex=True, 
                       sharey=True, squeeze=True)
plt.yticks([0,1,2])
fig.text(-0.05, 0.5, r"$\Delta m_{15}$", rotation=90)

for i,tp in enumerate(["Ibc","IIb", "Ib", "Ic","Ic-bl", "Ibn"]):
    #print(i//2, i%2)
    plotDms(tp, dm15, ax[i], grid=True, rot=90)
fig.tight_layout(pad=-0.3)
plt.savefig("dm15_subplots.png")

# %%
fig, ax = plt.subplots(3,2, figsize=(10,5), sharex=True, 
                       sharey=True, squeeze=True)
plt.yticks([0,1,2])
fig.text(-0.03, 0.5, r"$\Delta m_{-10}$", rotation=90)

for i,tp in enumerate(["Ibc","IIb", "Ib", "Ic","Ic-bl"]):
    plotDms(tp, dm10, ax[i//2, i%2], grid=True, rot=90)
ax[2,1].axis('off')
ax[1,1].set_xticks(np.arange(len(dm10["filter"])*2)[::2] + 0.5, 
                  dm10['filter'], rotation=90) ;

fig.tight_layout(pad=0)
for i,l in enumerate(dm10['filter']):
    ax[1,1].text(i * 2 + 0.5, -1, l, rotation=90, ha="center", va="top")
    
plt.savefig("dm10_subplots.png")
