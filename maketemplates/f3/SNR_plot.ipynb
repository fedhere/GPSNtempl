# %%
import os
import pickle as pkl
import sys
import numpy as np
import pandas as pd
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
from scipy.interpolate import InterpolatedUnivariateSpline
# print ("bokeh version", bokeh.__version__)
#, HBox, VBoxForm, BoxSelectTool, TapTool
#from bokeh.models.widgets import Select
#Slider, Select, TextInput
# from bokeh.plotting import output_file
# import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
try:
    os.environ['SESNPATH']
except KeyError:
    print ("must set environmental variable SESNPATH")
    sys.exit()

cmd_folder = os.getenv("SESNPATH")+'/utils'
if cmd_folder not in sys.path:
    sys.path.insert(0, cmd_folder)

from snclasses import *
import snclasses as snstuff
from templutils import *

# %matplotlib inline

# %%
LN10on2p5
# Out:
# 0.9210340371976183

# %%
np.log(10*2**5)
# Out:
# 5.768320995793772

# %%
su = setupvars()

# %%
allsne = pd.read_csv(os.getenv("SESNPATH") +
                          "/utils/SESNessentials.csv", encoding = "ISO-8859-1")['SNname'].values

# %%
'''
Here we are calculating SNR for each SN in each band as follows:
SNR = flux/dflux for each data point

We then collect SNRs of all the data points in bands as below:
['U', 'u', 'B', 'V', 'R', 'I', 'g', 'r', 'i', 'J', 'H', 'K', 'w1', 'w2', 'm2']

'''


temp = []

snrs = []
bands = []
names = []

fluxes = []

dmags_all = []
lcmags_all = []



lc_ = {}
# bands = su.bands

for i, sn in enumerate(allsne):
    
#     snr['sn'].append(sn)
    
    # read and set up SN and look for photometry files
    try:
        thissn = snstuff.mysn(sn, addlit=True)
    except AttributeError:
        print('removed sn: ', sn)
        continue
    if len(thissn.optfiles) + len(thissn.fnir) == 0:
        print ("bad sn")
    # read metadata for SN
    thissn.readinfofileall(verbose=False, earliest=False, loose=True)
    thissn.setVmax()

    lc, flux, dflux, snname = thissn.loadsn2()
    # set up photometry
    # thissn.printsn()
    thissn.setphot()
    thissn.getphot()
    thissn.setphase()
    
    # check SN is ok and load data
    if thissn.Vmax is None or thissn.Vmax == 0 or np.isnan(thissn.Vmax):
        print ("bad sn: No Vmax")
  

    # lc, flux, dflux, snname = thissn.loadsn2(verbose=True)
    
    
    
    
#     lc['dmag'][lc['dmag']==0] = 0.1*np.ones(len(lc['dmag'][lc['dmag']==0]))
    
    lc_mag = lc['ccmag'][lc['dmag'] >= 0.01]
    lc_photcode = lc['photcode'][lc['dmag'] >= 0.01]
    lc_dmag = lc['dmag'][lc['dmag'] >= 0.01]
    
    
    
    flux = 10 ** (-lc_mag / 2.5) * 5e8
    dflux = flux * lc_dmag * LN10on2p5
    
        
    # flux = 10 ** (-lc_mag / 2.5) 
    # dflux = flux * np.log(10) * lc_dmag / 2.5
        
    
#     if len(lc['photcode']) != len(flux/dflux):
#         temp.append(sn)
    snr_ratio = flux/dflux
    
        
    
    photcode = [lc_photcode[i].decode().split('l')[0] for i in range(len(lc_photcode))]
    
    if len(np.setdiff1d(np.unique(photcode), su.bands, assume_unique=False)) != 0:
        # If there are bands that we don't want, remove their snrs.
        
        dd = (np.setdiff1d(np.unique(photcode), su.bands, assume_unique=False))
        for d in dd:
        
            snr_ratio = np.asarray(snr_ratio)[np.asarray(photcode) != str(d[0])]
            photcode = np.asarray(photcode)[np.asarray(photcode) != str(d[0])]
        
    

    
    thissn.setphot()
    thissn.getphot()
    thissn.setphase()
    thissn.sortlc()
    
    names_tmp = np.array([sn for i in range(len(snr_ratio))])
    
    
        
    snrs = np.concatenate((snrs, snr_ratio), axis = 0)
    fluxes = np.concatenate((fluxes, flux), axis = 0)
    bands = np.concatenate((bands, photcode), axis = 0)
    names = np.concatenate((names, names_tmp), axis = 0)
    dmags_all = np.concatenate((dmags_all, lc_dmag), axis = 0)
    lcmags_all = np.concatenate((lcmags_all, lc_mag), axis = 0)
    
plt.hist(np.log10(fluxes))
print(np.min(fluxes))
# plt.xscale('log')
# Out:
# SN name short: ASASSN-14ms
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.snASASSN-14ms.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2457023.99
# 0
# SN name short: DES16s1kt
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.DES16S1KT.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2457641.7
# SN name short: iPTF13bvn
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sniPTF13bvn.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2456476.32
# 0
# SN name short: iPTF15dld
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.iptf15dld.f', '/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sniPTF15dld.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2457307.98
# loading lit data
# trying again /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sniPTF15dld.f
# SN name short: iPTF15dtg
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sniPTF15dtg.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2457353.86
# 0
# SN name short: LSQ13ccw
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.snLSQ13ccw.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2456538.95
# 0
# SN name short: LSQ14efd
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.snLSQ14efd.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2456900.03
# 0
# SN name short: OGLE-2012-sn-006
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.snOGLE-2012-SN-006.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2456215.88
# 13
# SN name short: OGLE-2013-sn-091
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.snOGLE-2013-SN-091.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2456578.05
# 0
# SN name short: OGLE-2013-sn-134
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.snOGLE-2013-SN-134.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2456636.89
# 0
# SN name short: OGLE-2014-sn-014
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.snOGLE-2014-SN-014.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2456697.35
# 0
# SN name short: OGLE-2014-sn-131
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.snOGLE-2014-SN-131.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2456969.14
# 0
# SN name short: OGLE15eo
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.snOGLE15eo.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2457263.67
# 0
# SN name short: OGLE15jy
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.snOGLE15jy.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2457298.11
# 0
# SN name short: OGLE15rb
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.snOGLE15rb.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2457341.03
# 0
# SN name short: OGLE15vk
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.snOGLE15vk.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2457357.36
# 0
# SN name short: OGLE16ekf
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.snOGLE16ekf.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2457680.0
# SN name short: PS1-12sk
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.snPS1-12sk.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2456003.74
# 9
# SN name short: PTF10qts
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.PTF10qts.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2455428.19
# removed sn:  #PTF11iqb
# SN name short: PTF11kmb
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.snPTF11kmb.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2455799.74
# 0
# SN name short: PTF11qcj
#
#
#
# #######Optical & UV#######
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/ASASSN-14ms.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/iPTF13bvn.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/iPTF15dtg.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/LSQ13ccw.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/LSQ14efd.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/OGLE-2013-sn-091.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/OGLE-2013-sn-134.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/OGLE-2014-sn-014.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/OGLE-2014-sn-131.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/OGLE15eo.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/OGLE15jy.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/OGLE15rb.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/OGLE15vk.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/PTF11kmb.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/PTF11qcj.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.snPTF11qcj.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2455842.34
# 0
# SN name short: PTF12gzk
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.snPTF12gzk.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2456149.88
# 21
# SN name short: PTF12hni
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.snPTF12hni.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2456170.66
# 0
# SN name short: SDSS-II14475
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.snSDSS-II14475.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2454020.285
# SN name short: SDSS-II19065
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.snSDSS-II19065.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2454393.71
# SN name short: SDSS-II19190
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.snSDSS-II19190.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2454414.035
# SN name short: SDSS-II4664
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.snSDSS-II4664.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2453673.395
# SN name short: SDSS-II5339
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.snSDSS-II5339.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2453652.38
# SN name short: SDSS-II6861
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.snSDSS-II6861.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2453673.445
# SN name short: SDSS-II8196
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.snSDSS-II8196.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2453680.485
# SN name short: 54A
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn54A.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2434850.3499999996
# 0
# SN name short: 62L
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn62L.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2438008.31
# 0
# SN name short: 83N
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn83N.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2445529.36
# 0
# SN name short: 83V
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn83V.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2445681.44
# 0
# SN name short: 84I
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn84I.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2445847.82
# 0
# SN name short: 85F
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn85F.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2445871.13
# 0
# SN name short: 91N
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn91N.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2448348.95
# 0
# SN name short: 93J
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn93J.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2449095.23
# 0
# SN name short: 94I
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn94I.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2449451.9
# 0
# SN name short: 96cb
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn96cb.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2450452.68
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/PTF12hni.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/54A.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/62L.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/83N.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/83V.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/84I.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/85F.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/91N.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/93J.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/94I.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/96cb.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/97ef.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/98bw.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# 0
# SN name short: 97ef
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn97ef.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2450793.25
# 0
# SN name short: 98bw
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn98bw.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2450945.46
# 0
# SN name short: 99dn
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn99dn.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2451419.06
# SN name short: 99ex
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn99ex.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2451501.33
# 0
# SN name short: 01ig
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn01ig.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2452273.4
# 0
# SN name short: 02ap
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn02ap.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2452314.47
# 0
# SN name short: 02ji
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn02ji.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2452620.87
# SN name short: 03bg
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn03bg.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2452721.02
# 0
# SN name short: 03dh
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn03dh.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2452740.63
# 15
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/99ex.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/01ig.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/02ap.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/03bg.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/03id.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/03jd.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/04aw.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/04dk.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# SN name short: 03id
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn03id.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2452911.76
# 0
# SN name short: 03jd
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn03jd.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2452943.31
# 0
# removed sn:  #sn2003lw
# SN name short: 04aw
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn04aw.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2453091.45
# 0
# SN name short: 04dk
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn04dk.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2453243.92
# 0
# SN name short: 04dn
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn04dn.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2453231.12
# 0
# SN name short: 04ex
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn04ex.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2453308.41
# 32
# SN name short: 04fe
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn04fe.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2453319.34
# 0
# SN name short: 04ff
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn04ff.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2453314.92
# 12
# SN name short: 04ge
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn04ge.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2453335.57
# 0
# removed sn:  #sn2004gk
# SN name short: 04gq
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn04gq.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2453363.02
# 23
# SN name short: 04gt
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn04gt.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2453363.07
# 61
# SN name short: 04gv
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn04gv.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2453367.35
# 23
# SN name short: 05az
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn05az.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2453473.86
# 68
# SN name short: 05bf
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn05bf.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2453498.96
# 155
# SN name short: 05by
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn05by.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2453504.05
# 0
# SN name short: 05em
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn05em.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2453648.62
# 22
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/04dn.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/04fe.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/04ge.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/05by.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/05fk.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/05hl.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/05hm.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# SN name short: 05fk
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn05fk.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2453627.55
# 0
# SN name short: 05hg
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn05hg.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2453684.44
# 93
# SN name short: 05hl
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn05hl.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2453632.1399999997
# 0
# SN name short: 05hm
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn05hm.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2453651.98
# 0
# SN name short: 05kl
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn05kl.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2453703.66
# 72
# SN name short: 05kr
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn05kr.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2453690.5599999996
# 0
# SN name short: 05ks
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn05ks.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2453691.46
# 0
# SN name short: 05kz
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn05kz.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2453712.94
# 0
# SN name short: 05mf
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn05mf.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2453734.56
# 49
# SN name short: 06aj
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn06aj.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2453794.7
# 17
# SN name short: 06ba
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn06ba.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2453825.71
# 23
# SN name short: 06bf
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn06bf.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2453826.53
# 19
# SN name short: 06cb
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn06cb.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2453861.48
# 0
# SN name short: 06el
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn06el.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2453984.68
# 0
# SN name short: 06ep
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn06ep.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2453988.58
# 36
# SN name short: 06fo
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn06fo.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2454005.61
# 95
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/05kr.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/05ks.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/05kz.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/06cb.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/06el.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/06jo.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# SN name short: 06ir
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn06ir.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2454015.3099999996
# 40
# SN name short: 06jc
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn06jc.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2454020.0
# 264
# SN name short: 06jo
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn06jo.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2454016.62
# 0
# SN name short: 06lc
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn06lc.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2454041.35
# 16
# removed sn:  #sn2006lv
# SN name short: 06nx
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn06nx.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2454056.125
# 0
# removed sn:  #sn2006sg
# SN name short: 06T
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn06T.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2453782.06
# 96
# SN name short: 07ag
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn07ag.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2454170.26
# 13
# SN name short: 07ay
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn07ay.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2454200.42
# 0
# removed sn:  #sn2007bg
# SN name short: 07C
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn07C.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2454116.95
# 152
# SN name short: 07ce
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn07ce.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2454226.7249999996
# 19
# SN name short: 07cl
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn07cl.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2454250.85
# 0
# SN name short: 07d
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn07d.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2454123.31
# 14
# SN name short: 07gr
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn07gr.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2454339.32
# 196
# SN name short: 07I
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn07I.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/06nx.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/07ay.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/07cl.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/07ke.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/07ms.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# ...
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/12hn.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/12P.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/13ak.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/13cq.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/13cu.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/13df.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/13dk.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/13ge.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/14ad.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/14C.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/14L.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/15ap.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/15U.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# SN name short: 12P
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn12P.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2455951.885
# 0
# SN name short: 13ak
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn13ak.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2456369.15
# 0
# SN name short: 13cq
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn13cq.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2456433.5
# 0
# SN name short: 13cu
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn13cu.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2456424.35
# 0
# SN name short: 13df
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn13df.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2456470.01
# 0
# SN name short: 13dk
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn13dk.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2456476.47
# 0
# SN name short: 13ge
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn13ge.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2456621.43
# 0
# SN name short: 14ad
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn14ad.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2456741.29
# 0
# SN name short: 14C
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn14C.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2456671.19
# 0
# SN name short: 14L
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn14L.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2456695.7
# 0
# SN name short: 15ap
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn15ap.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2457287.44
# 0
# SN name short: 15U
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn15U.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2457071.39
# 0
# SN name short: 16bau
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn16bau.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2457478.78
# 0
# SN name short: 16gkg
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn16gkg.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2457672.2
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/16bau.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/16gkg.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/16hgs.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/17ein.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/19all.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/19bjv.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/19gqd.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/19ilo.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# /Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl//utils/snclasses.py:5322: UserWarning: loadtxt: input contained no data: "/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/nirphot/19pik.dat"
#   self.nirlc = np.loadtxt(f, usecols=(0, 1, 2, 3), \
# 0
# SN name short: 16hgs
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn16hgs.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2457690.875
# 0
# SN name short: 17ein
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn17ein.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2457914.6049999995
# 0
# SN name short: 19all
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn19all.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2458538.15
# 0
# SN name short: 19bjv
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn19bjv.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2458530.56
# 0
# SN name short: 19gqd
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn19gqd.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2458646.4899999998
# 0
# SN name short: 19ilo
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn19ilo.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2458679.24
# 0
# SN name short: 19pik
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn19pik.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2458734.85
# 0
# SN name short: 19myn
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn19myn.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2458705.96
# SN name short: 19deh
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn19deh.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2458587.085
# SN name short: 19php
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn19php.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2458730.29
# SN name short: 19rii
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn19rii.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2458755.9
# SN name short: 18bcc
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn18bcc.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2458232.35
# SN name short: 19aajs
#
#
#
# #######Optical & UV#######
#
# No CfA optical files
# all optical files: ['/Users/somayeh/Library/Mobile Documents/com~apple~CloudDocs/Research/SNe_templates/GPSNtempl/literaturedata/phot/slc.sn19aajs.f']
#
#
# #######NIR#######
#
# No CfA NIR files
# reading small file
# Vmax 2458540.9
# 0.0025666675064712763

# %%
snr = pd.DataFrame({'SNR': snrs, 'Band': bands})

# %%
snr
# Out:
#              SNR Band
# 0      25.850864    U
# 1      25.850861    U
# 2      29.344223    U
# 3      22.619505    B
# 4      23.100771    B
# ...          ...  ...
# 28821   3.502375    r
# 28822  15.510518    u
# 28823  10.857362    u
# 28824  10.857361    u
# 28825   5.428681    u
#
# [28826 rows x 2 columns]

# %%
snr['order'] = 0

# %%
order= {'w1':0, 'w2':1, 'm2':2, 'u/U':3, 'V':4, 'B':5, 'g':6, 'r/R':7, 'i/I':8, 'J':9, 'H':10, 'K':11}

# %%
snr['Band'].loc[(snr['Band'] == 'i') | (snr['Band'] == 'I')] = 'i/I'
snr['Band'].loc[(snr['Band'] == 'r') | (snr['Band'] == 'R')] = 'r/R'
snr['Band'].loc[(snr['Band'] == 'u') | (snr['Band'] == 'U')] = 'u/U'
# Out:
# /var/folders/6f/k2kn3hn52ws4kc_w0_zqfpy40000gp/T/ipykernel_25884/4066914702.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   snr['Band'].loc[(snr['Band'] == 'i') | (snr['Band'] == 'I')] = 'i/I'
# /var/folders/6f/k2kn3hn52ws4kc_w0_zqfpy40000gp/T/ipykernel_25884/4066914702.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   snr['Band'].loc[(snr['Band'] == 'r') | (snr['Band'] == 'R')] = 'r/R'
# /var/folders/6f/k2kn3hn52ws4kc_w0_zqfpy40000gp/T/ipykernel_25884/4066914702.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   snr['Band'].loc[(snr['Band'] == 'u') | (snr['Band'] == 'U')] = 'u/U'

# %%
snr.Band.map(order)
# Out:
# 0        3
# 1        3
# 2        3
# 3        5
# 4        5
#         ..
# 28821    7
# 28822    3
# 28823    3
# 28824    3
# 28825    3
# Name: Band, Length: 28826, dtype: int64

# %%
snr['order'] = snr.Band.map(order)

# %%
snr.sort_values(by='order', inplace=True)

# %%
snr
# Out:
#              SNR Band  order
# 22665   4.159909   w1      0
# 24923  14.476482   w1      0
# 24922  14.286003   w1      0
# 24921  14.286004   w1      0
# 24920  14.100471   w1      0
# ...          ...  ...    ...
# 13420   6.204207    K     11
# 13419  12.479727    K     11
# 13418  12.337912    K     11
# 13426   8.549104    K     11
# 18902  31.021036    K     11
#
# [28826 rows x 3 columns]

# %%
import seaborn as sns
plt.figure(figsize=(20,10))
sns.set_theme(style="whitegrid")
palette = sns.color_palette("coolwarm", n_colors =12)
ax = sns.violinplot(x="Band", y="SNR", data=snr, palette = palette, cut=0)
ax.tick_params(axis='both', which='major', labelsize=20)
ax.xaxis.label.set_size(30)
ax.yaxis.label.set_size(30)
# ax.set_ylim((0,700))
plt.savefig(os.getenv("SESNPATH")+ 'maketemplates/outputs/output_plots/SNR_plot_add_Ibns_modified.pdf', bbox_inches='tight')

# %%
for b in snr.Band.unique():
    
    print(b, np.median(snr.SNR[snr.Band == b].values))
# Out:
# w1 9.441184043884277
# w2 7.755258560180664
# m2 12.063735008239746
# u/U 19.048004150390625
# V 43.429447174072266
# B 29.344223022460938
# g 27.839387893676758
# r/R 38.77629089355469
# i/I 36.19120788574219
# J 25.850862503051758
# H 16.577091217041016
# K 11.194346904754639
